# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
X = housing.data
y = housing.target

# %%
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
housing.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
##lets check the description of the dataset
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surprisingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. rubric:: References
#
# - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#   Statistics and Probability Letters, 33:291-297, 1997.

# %%
print(housing.data)
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
print(housing.target)
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %%
print(housing.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %% [markdown]
# ## Preparing The Dataset

# %%
dataset=pd.DataFrame(housing.data,columns=housing.feature_names)

# %%
dataset
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
dataset['price']=housing.target

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
## Summarizing The Stats of the data
dataset.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010

# %%
## checking the missing values
dataset.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# price         0
# dtype: int64

# %%
## EDA
## Correlation
dataset.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# Population -0.108785   0.099773 -0.024650
# AveOccup    0.002366   0.002476 -0.023737
# Latitude    1.000000  -0.924664 -0.144160
# Longitude  -0.924664   1.000000 -0.045967
# price      -0.144160  -0.045967  1.000000

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
plt.scatter(dataset['MedInc'],dataset['price'])
plt.xlabel("Medinc Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset['HouseAge'],dataset['price'])
plt.xlabel("HouseAge")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset['AveRooms'],dataset['price'])
plt.xlabel("AveRooms")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset['AveBedrms'],dataset['price'])
plt.xlabel("AveBedrms")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset['Population'],dataset['price'])
plt.xlabel("Population")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset['AveOccup'],dataset['price'])
plt.xlabel("AveOccup")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset['Latitude'],dataset['price'])
plt.xlabel("Latitude")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(dataset['Longitude'],dataset['price'])
plt.xlabel("Longitude")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
import seaborn as sns
sns.regplot(x="MedInc",y="price",data=dataset)
# Out:
# <Axes: xlabel='MedInc', ylabel='price'>

# %%
import seaborn as sns
sns.regplot(x="AveRooms",y="price",data=dataset)
# Out:
# <Axes: xlabel='AveRooms', ylabel='price'>

# %%
import seaborn as sns
sns.regplot(x="Longitude",y="price",data=dataset)
# Out:
# <Axes: xlabel='Longitude', ylabel='price'>

# %%
import seaborn as sns
sns.regplot(x="Latitude",y="price",data=dataset)
# Out:
# <Axes: xlabel='Latitude', ylabel='price'>

# %%
## independent and dependent featues
X=dataset.iloc[:,:-1]
Y=dataset.iloc[:,-1]

# %%
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
Y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: price, Length: 20640, dtype: float64

# %%
## train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 7061   4.1312      35.0  5.882353   0.975490      1218.0  2.985294     33.93
# 14689  2.8631      20.0  4.401210   1.076613       999.0  2.014113     32.79
# 17323  4.2026      24.0  5.617544   0.989474       731.0  2.564912     34.59
# 10056  3.1094      14.0  5.869565   1.094203       302.0  2.188406     39.26
# 15750  3.3068      52.0  4.801205   1.066265      1526.0  2.298193     37.77
# ...       ...       ...       ...        ...         ...       ...       ...
# 11284  6.3700      35.0  6.129032   0.926267       658.0  3.032258     33.78
# 11964  3.0500      33.0  6.868597   1.269488      1753.0  3.904232     34.02
# 5390   2.9344      36.0  3.986717   1.079696      1756.0  3.332068     34.03
# 860    5.7192      15.0  6.395349   1.067979      1777.0  3.178891     37.58
# 15795  2.5755      52.0  3.402576   1.058776      2619.0  2.108696     37.77
#
#        Longitude
# 7061     -118.02
# 14689    -117.09
# 17323    -120.14
# 10056    -121.00
# 15750    -122.45
# ...          ...
# 11284    -117.96
# 11964    -117.43
# 5390     -118.38
# 860      -121.96
# 15795    -122.42
#
# [14448 rows x 8 columns]

# %%
x_test
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20046  1.6812      25.0  4.192201   1.022284      1392.0  3.877437     36.06
# 3024   2.5313      30.0  5.039384   1.193493      1565.0  2.679795     35.14
# 15663  3.4801      52.0  3.977155   1.185877      1310.0  1.360332     37.80
# 20484  5.7376      17.0  6.163636   1.020202      1705.0  3.444444     34.28
# 9814   3.7250      34.0  5.492991   1.028037      1063.0  2.483645     36.62
# ...       ...       ...       ...        ...         ...       ...       ...
# 17505  2.9545      47.0  4.195833   1.020833       581.0  2.420833     37.36
# 13512  1.4891      41.0  4.551852   1.118519       994.0  3.681481     34.11
# 10842  3.5120      16.0  3.762287   1.075614      5014.0  2.369565     33.67
# 16559  3.6500      10.0  5.502092   1.060371      5935.0  3.547519     37.82
# 5786   3.0520      17.0  3.355781   1.019695      4116.0  2.614994     34.15
#
#        Longitude
# 20046    -119.01
# 3024     -119.46
# 15663    -122.44
# 20484    -118.72
# 9814     -121.93
# ...          ...
# 17505    -121.90
# 13512    -117.32
# 10842    -117.91
# 16559    -121.28
# 5786     -118.24
#
# [6192 rows x 8 columns]

# %%
y_train
# Out:
# array([1.938, 1.697, 2.598, ..., 2.221, 2.835, 3.25 ], shape=(14448,))

# %%
y_test
# Out:
# array([0.477  , 0.458  , 5.00001, ..., 2.184  , 1.194  , 2.098  ],
#       shape=(6192,))

# %%
## standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[ 0.13350629,  0.50935748,  0.18106017, ..., -0.01082519,
#         -0.80568191,  0.78093406],
#        [-0.53221805, -0.67987313, -0.42262953, ..., -0.08931585,
#         -1.33947268,  1.24526986],
#        [ 0.1709897 , -0.36274497,  0.07312833, ..., -0.04480037,
#         -0.49664515, -0.27755183],
#        ...,
#        [-0.49478713,  0.58863952, -0.59156984, ...,  0.01720102,
#         -0.75885816,  0.60119118],
#        [ 0.96717102, -1.07628333,  0.39014889, ...,  0.00482125,
#          0.90338501, -1.18625198],
#        [-0.68320166,  1.85715216, -0.82965604, ..., -0.0816717 ,
#          0.99235014, -1.41592345]], shape=(14448, 8))

# %%
x_test
# Out:
# array([[-1.1526893 , -0.28346293, -0.50781822, ...,  0.06127763,
#          0.19166399,  0.28664112],
#        [-0.70640568,  0.11294728, -0.16252032, ..., -0.03551561,
#         -0.23911452,  0.06196251],
#        [-0.20830675,  1.85715216, -0.59546738, ..., -0.14215427,
#          1.00639726, -1.42590916],
#        ...,
#        [-0.19155996, -0.99700129, -0.6830438 , ..., -0.06058827,
#         -0.92742367,  0.8358555 ],
#        [-0.11911302, -1.47269353,  0.02607207, ...,  0.03461374,
#          1.01576201, -0.84673764],
#        [-0.43304974, -0.91771925, -0.84872893, ..., -0.0407528 ,
#         -0.70266966,  0.67109119]], shape=(6192, 8))

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## print the coefficients and the intercept
print(regression.coef_)
# Out:
# [ 8.49221760e-01  1.22119309e-01 -2.99558449e-01  3.48409673e-01
#  -8.84488134e-04 -4.16980388e-02 -8.93855649e-01 -8.68616688e-01]

# %%
print(regression.intercept_)
# Out:
# 2.0692396089424165

# %%
#on which parameters the model have been trained
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
## prediction with test data
reg_pred=regression.predict(x_test)

# %%
reg_pred
# Out:
# array([0.72604907, 1.76743383, 2.71092161, ..., 2.07465531, 1.57371395,
#        1.82744133], shape=(6192,))

# %%
## plot a scatter plot for the prediction
plt.scatter(y_test,reg_pred)

# %%
residuals=y_test-reg_pred

# %%
residuals
# Out:
# array([-0.24904907, -1.30943383,  2.28908839, ...,  0.10934469,
#        -0.37971395,  0.27055867], shape=(6192,))

# %%
##plot this residuals
sns.distplot(residuals,kde=True)
plt.show
# Out:
# C:\Users\SAI VARSHA\AppData\Local\Temp\ipykernel_36132\214849599.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals,kde=True)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## scatter plot with respect to prediction and residuals
plt.scatter(reg_pred,residuals)

# %%
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 0.5272474538305952
# 0.5305677824766752
# 0.7284008391515452

# %% [markdown]
# ## R Square and adjusted R square
# formula
# ### R^2=1-SSR/SST
# R^2=coefficient of determination SSR=sum of squares of residuals SST=total sum of squares

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.5957702326061665

# %% [markdown]
# ## Adjusted R2=1-[(1-R2)*(n-1)(n-k-1)]
# where:
# R2: The R2 of the model n:The num of observations k:The num of predictor variables

# %%
## display adjusted R-Squared
1-(1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.5952472117200027

# %% [markdown]
# ## New Data Prediction

# %%
housing.data[0].reshape(1,-1)
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698,    1.02380952,
#          322.        ,    2.55555556,   37.88      , -122.23      ]])

# %%
## transformation of new data
scaler.transform(housing.data[0].reshape(1,-1))
# Out:
# c:\Users\SAI VARSHA\Downloads\end to end project\venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 2.33526315,  0.98504972,  0.63012521, -0.16586931, -0.96995366,
#         -0.04555657,  1.04385626, -1.32105914]])

# %%
regression.predict(scaler.transform(housing.data[0].reshape(1,-1)))
# Out:
# c:\Users\SAI VARSHA\Downloads\end to end project\venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([4.14333441])

# %% [markdown]
# ## Pickling The Model For Deployment

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('regmodel.pkl','rb'))

# %%
## prediction
pickled_model.predict(scaler.transform(housing.data[0].reshape(1,-1)))
# Out:
# c:\Users\SAI VARSHA\Downloads\end to end project\venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([4.14333441])

# %%
import os
os.path.exists("regmodel.pkl")
# Out:
# True

# %%
import os
print(os.getcwb())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 2
#       1 import os
# ----> 2 print(os.getcwb())
#
# AttributeError: module 'os' has no attribute 'getcwb'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\SAI VARSHA

# %%
import os
print(os.listdir())
# Out:
# ['.anaconda', '.android', '.angular-config.json', '.bash_history', '.conda', '.continuum', '.copilot', '.ghcp-appmod', '.ghcp-appmod-java', '.gitconfig', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.lesshst', '.matplotlib', '.node_repl_history', '.pyforest', '.quokka', '.thumbnails', '.vscode', '.vscode-shared', '.wallaby', '9th march', 'Advertising.csv', 'anaconda3', 'ANN-20260428T095326Z-3-001.zip', 'ANN_using_Sklearn.ipynb', 'AppData', 'Application Data', 'archive (2).zip', 'Car_Price_Prediction.ipynb', 'CNN_Python_Implementation.ipynb', 'Contacts', 'Cookies', 'Customer_Transaction_Prediction.ipynb', 'data.csv', 'Datamites(Keerty)', 'DataVisualization.ipynb', 'DecisionTree_RandomForest_preprocessing.ipynb', 'Decision_tree1.png', 'Desktop', 'diabetes.csv', 'diabetes1.csv', 'Documents', 'Downloads', 'Favorites', 'FeatureEngine.ipynb', 'Final_DT_RF_GB_XGB_implementation.ipynb', 'Fish[1].csv', 'Flight_Fare.csv', 'Flight_Fare.xlsx', 'Flight_Fare_Prediction.ipynb', 'global_inflation_post_covid.csv', 'Heart_disease_prediction.ipynb', 'house prices.docx', 'House_Price_Prediction.ipynb', 'Hyderabad_Uber_Dataset.csv', 'IntelGraphicsProfiles', 'iris.csv', 'K-Means Algo.ipynb', 'KNN-20260414T094603Z-3-001.zip', 'KNN.ipynb', 'labels.csv', 'Linear Regression ML Implementation .ipynb', 'Linear Regression-20260331T064419Z-1-001.zip', 'loan_approved.csv', 'Local Settings', 'logistic regression.pdf', 'logistic regression.txt', 'Machine learning.ipynb', 'main_data.csv', 'Microsoft', 'ml project.ipynb', 'mla.ipynb', 'mobile_price_dataset.csv', 'Music', 'My Documents', 'myfile.txt', 'NetHood', 'New folder (4)', 'node_modules', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{cefc5fd1-f38c-11ef-af41-f2a8fd712538}.TM.blf', 'NTUSER.DAT{cefc5fd1-f38c-11ef-af41-f2a8fd712538}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{cefc5fd1-f38c-11ef-af41-f2a8fd712538}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'output.csv', 'pandas prac.ipynb', 'pandas-9thMarch_CDS', 'PCA-20260413T093734Z-3-001.zip', 'PCA.ipynb', 'PCA_intro1.png', 'Pictures', 'pp2.ipynb', 'preprocessing.ipynb', 'PrintHood', 'python prac.ipynb', 'Recent', 'regex.ipynb', 'regmodel.pkl', 'Saved Games', 'scikit_learn_data', 'Searches', 'SendTo', 'SinglePageApp', 'Start Menu', 'SVM_Implementation.ipynb', 'task1.ipynb', 'Templates', 'Test.csv', 'Test.png', 'titanic_train.csv', 'train (2).csv', 'train(1).csv', 'Tree based algorithms_DT_RF_GB_XGB-20260506T160941Z-3-001.zip', 'UberDataset.csv', 'Uberridesp1.ipynb', 'Untitled (1).ipynb', 'Untitled.ipynb', 'untitled.py', 'Untitled1.ipynb', 'Untitled10.ipynb', 'Untitled11.ipynb', 'Untitled12.ipynb', 'Untitled13.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Untitled6.ipynb', 'Untitled7.ipynb', 'Untitled8.ipynb', 'Untitled9.ipynb', 'values.csv', 'venv', 'Videos', 'Zomato-data-.csv', '~$Random_Forest_and_Gradient_Boosting.pptx']

# %%
import os

print(os.listdir("Downloads"))
# Out:
# ['.ipynb_checkpoints', '01_TGEAPCET_2024_FirstPhase_LastRanks (1).xlsx', '01_TGEAPCET_2024_FirstPhase_LastRanks (2).xlsx', '01_TGEAPCET_2024_FirstPhase_LastRanks (3).xlsx', '01_TGEAPCET_2024_FirstPhase_LastRanks.xlsx', '06march2026-demo2ndcommit.zip', '0bb87bfac3b5a73e254535a6b196bda6.jpg', '1 . EDA STUDENT PERFORMANCE .ipynb', '1733662493 (1).pdf', '1733662493.pdf', '1733848460.pdf', '2. MODEL TRAINING.ipynb', '244711136_20240626085456.jpg', '282022_2228337633_2228337633_20062024160123.pdf', '6868626.jpg', '9 march', '96c715da-18f7-4530-9673-8f56f4a35622-1742816048773-4102632515857253.pdf', '99_cropped_processed_by_imagy.jpg', 'ADSI_Table_1A.2.csv', 'AFM - KEY-1.docx', 'Anaconda3-2025.12-1-Windows-x86_64.exe', 'ANN-20260428T095326Z-3-001', 'ANN-20260428T095326Z-3-001.zip', 'Annual report 2020-21.pdf.pdf', 'AnyDesk.exe', 'Apocolypse Food Prep - Bins Lists Tutorial.xlsx', 'Apocolypse Food Prep - Conditional Formatting Tutorial.xlsx', 'Apocolypse Food Prep - DAX Tutorial.xlsx', 'Apocolypse Food Prep - Drill Down Tutorial.xlsx', 'Apocolypse Food Prep - Power Query Editor Tutorial.xlsx', 'Apocolypse Food Prep - Relationship Tutorial.xlsx', 'Apocolypse Food Prep - Visualizations Tutorial.xlsx', 'Apocolypse Food Prep.xlsx', 'AR2023EN (1).pdf', 'AR2023EN.pdf', 'archive', 'archive (1).zip', 'archive (2)', 'archive (2).zip', 'archive (3)', 'archive (3).zip', 'archive.zip', 'Assignment-1.docx', 'Assignment-2.docx', 'awesome-telugu', 'awesome-telugu.zip', 'b57b445e-7994-4104-af5d-5a022a425673Challuri_varshini_resume__7_.docx', 'blender-4.1.1-windows-x64.msi', 'C - Short Answer Questons.pdf', 'C imp Qns.pdf', 'CapCut Installer.exe', 'capcut-14-5-0.apk', 'car-1751268134394-4452.jpg', 'Car-Price Prediction-20260514T094611Z-3-001', 'Car-Price Prediction-20260514T094611Z-3-001.zip', 'Challuri varshini resume (1).docx', 'Challuri varshini Resume (1).pdf', 'Challuri varshini resume (2).docx', 'Challuri varshini resume (3) (1).docx', 'Challuri varshini resume (3).docx', 'Challuri varshini resume (4).docx', 'Challuri varshini resume (5).docx', 'Challuri varshini resume (6).docx', 'Challuri varshini resume (7).docx', 'Challuri varshini resume.docx', 'Challuri varshini Resume.pdf', 'Challuri_Varshini_Resume.pdf', 'ChromeSetup (1).exe', 'ChromeSetup.exe', 'CNN_Python_Implementation.ipynb', 'college_fee_list (1).xls', 'college_fee_list.xls', 'Consent.html', 'Consent_files', 'CSS (OneShot)-20250718T101841Z-1-001.zip', 'Customer_Transaction_Prediction.ipynb', 'DAILY_CURRENT_AFFAIRS_TESTS_1712207460427.pdf', 'Data Science-20250718T101841Z-1-001.zip', 'DaVinci_Resolve_19.1.3_Windows', 'DaVinci_Resolve_19.1.3_Windows.zip', 'DaVinci_Resolve_19.1.4_Windows.zip', 'DaVinci_Resolve_20.0.1_Windows.zip', 'DBM-20260311T131303Z-1-001.zip', 'description(2).docx', 'Desktop - Shortcut.lnk', 'desktop.ini', 'diabetes1.csv', 'diabetes[1].csv', 'download.jpg', 'DT20246428603_Application.pdf', 'Economic Survey Complete PDF.pdf', 'end to end project', 'EPCET.pdf', 'EPCET2.pdf', 'FeatureEngine.ipynb', 'FEB CASE 10.pptx', 'Firefox Installer.exe', 'firstprogram.py', 'Fish[1]', 'Fish[1].csv', 'Fish[1].zip', 'flight-fare (4)', 'Flight_Fare_Prediction.ipynb', 'G1164014643101600_15-02-2026_22-24-34.271_APPLICATION.pdf', 'Git-2.51.2-64-bit.exe', 'Git-2.53.0-64-bit (1).exe', 'Git-2.53.0-64-bit.exe', 'GIT-20260311T131306Z-1-001.zip', 'Github Cheat Sheet-20250718T101841Z-1-001.zip', 'github-recovery-codes.txt', 'GSTR1 Report_06_25_to_06_25 json new.json', 'GSTR1 Report_06_25_to_06_25 new.xlsx', 'GSTR1 Report_06_25_to_06_25.xlsx', 'gst_offline_tool (4)', 'gst_offline_tool (4).zip', 'heart.jpg', 'Heart_disease_prediction.ipynb', 'house prices.docx', 'House_Price_Prediction.ipynb', 'HTML (OneShot)-20250718T101842Z-1-001.zip', 'image_processing20200817-16566-13lc2h2 (1).gif', 'image_processing20200817-16566-13lc2h2.gif', 'INDIAN_ECONOMY_TSPSC_BY_VIJAY_SIR_1711360219705.pdf', 'Install-Asphalt 9_ Legends-GooglePlayGames-Beta.exe', 'Install-GooglePlayGames-Beta.exe', 'JavaCodingPack-0.4.2.e ...

# %%
import os

print(os.listdir(r"Downloads\end to end project"))
# Out:
# ['.git', '.gitignore', 'LICENSE', 'README.md']

# %%
import pickle

pickle.dump(
    regression,
    open(r"Downloads\end to end project\regmodel.pkl", "wb")
)

# %%
import os

print(os.listdir(r"Downloads\end to end project"))
# Out:
# ['.git', '.gitignore', 'LICENSE', 'README.md', 'regmodel.pkl']

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import json

housing = fetch_california_housing()
df = pd.DataFrame(housing.data, columns=housing.feature_names)

sample = {
    "data": df.iloc[0].to_dict()
}

print(json.dumps(sample, indent=4))
# Out:
# {
#     "data": {
#         "MedInc": 8.3252,
#         "HouseAge": 41.0,
#         "AveRooms": 6.984126984126984,
#         "AveBedrms": 1.0238095238095237,
#         "Population": 322.0,
#         "AveOccup": 2.5555555555555554,
#         "Latitude": 37.88,
#         "Longitude": -122.23
#     }
# }
